# %% [markdown]
# ## Raw Data -> Cropped Data

# %%
import os
import glob
from PIL import Image
import re

def split_image(input_path: str, output_dir: str, prefix: str, rows: int, cols: int):
    img = Image.open(input_path)
    W, H = img.size

    tile_w = W // cols
    tile_h = H // rows

    for row in range(rows):
        for col in range(cols):
            left   = col * tile_w
            upper  = row * tile_h
            right  = (col + 1) * tile_w if col < cols - 1 else W
            lower  = (row + 1) * tile_h if row < rows - 1 else H

            tile = img.crop((left, upper, right, lower))
            tile_filename = f"{prefix}_r{row}_c{col}.png"
            tile.save(os.path.join(output_dir, tile_filename))
    print(f"[✓] '{prefix}' 분할 완료: {rows*cols}개 타일")

def split_folder(input_folder: str, output_root: str):
    """
    input_folder 안의 .png/.jpg 파일을 모두 찾아,
    파일명 패턴에 따라 16분할 혹은 32분할을 수행하고
    모든 타일을 output_root에 바로 저장.
    """
    if not os.path.isdir(input_folder):
        raise ValueError(f"입력 폴더가 존재하지 않습니다: {input_folder}")

    patterns = ("*.png", "*.PNG", "*.jpg", "*.JPG", "*.jpeg", "*.JPEG")
    img_paths = []
    for pat in patterns:
        img_paths.extend(glob.glob(os.path.join(input_folder, pat)))
    if not img_paths:
        print("※ 입력 폴더에 처리할 이미지 파일이 없습니다.")
        return

    os.makedirs(output_root, exist_ok=True)

    for img_path in img_paths:
        fname = os.path.basename(img_path)
        basename, _ = os.path.splitext(fname)

        # 숫자-only → 4×8, 'Image' prefix → 4×4, 그 외 기본 4×4
        if re.fullmatch(r"\d+", basename):
            rows, cols = 4, 8
        else:
            rows, cols = 4, 4

        split_image(img_path, output_root, prefix=basename, rows=rows, cols=cols)


if __name__ == "__main__":
    input_folder = "/Users/chonakyung/Library/CloudStorage/GoogleDrive-whskrud1007@gmail.com/내 드라이브/blood/Data/Raw_data/Train"
    output_root  = "/Users/chonakyung/Library/CloudStorage/GoogleDrive-whskrud1007@gmail.com/내 드라이브/blood/Data/Cropped_Data/Train"
    split_folder(input_folder, output_root)
# Out:
# [✓] '60' 분할 완료: 32개 타일
# [✓] '48' 분할 완료: 32개 타일
# [✓] '49' 분할 완료: 32개 타일
# [✓] '61' 분할 완료: 32개 타일
# [✓] '59' 분할 완료: 32개 타일
# [✓] '58' 분할 완료: 32개 타일
# [✓] '8' 분할 완료: 32개 타일
# [✓] '9' 분할 완료: 32개 타일
# [✓] '14' 분할 완료: 32개 타일
# [✓] '28' 분할 완료: 32개 타일
# [✓] '29' 분할 완료: 32개 타일
# [✓] '15' 분할 완료: 32개 타일
# [✓] '17' 분할 완료: 32개 타일
# [✓] '16' 분할 완료: 32개 타일
# [✓] '12' 분할 완료: 32개 타일
# [✓] '13' 분할 완료: 32개 타일
# [✓] '39' 분할 완료: 32개 타일
# [✓] '11' 분할 완료: 32개 타일
# [✓] '10' 분할 완료: 32개 타일
# [✓] '38' 분할 완료: 32개 타일
# [✓] '35' 분할 완료: 32개 타일
# [✓] '21' 분할 완료: 32개 타일
# [✓] '20' 분할 완료: 32개 타일
# [✓] '34' 분할 완료: 32개 타일
# [✓] '22' 분할 완료: 32개 타일
# [✓] '36' 분할 완료: 32개 타일
# [✓] '37' 분할 완료: 32개 타일
# [✓] '23' 분할 완료: 32개 타일
# [✓] '27' 분할 완료: 32개 타일
# [✓] '33' 분할 완료: 32개 타일
# [✓] '32' 분할 완료: 32개 타일
# [✓] '26' 분할 완료: 32개 타일
# [✓] '18' 분할 완료: 32개 타일
# [✓] '30' 분할 완료: 32개 타일
# [✓] '24' 분할 완료: 32개 타일
# [✓] '25' 분할 완료: 32개 타일
# [✓] '31' 분할 완료: 32개 타일
# [✓] '19' 분할 완료: 32개 타일
# [✓] '4' 분할 완료: 32개 타일
# [✓] '56' 분할 완료: 32개 타일
# [✓] '42' 분할 완료: 32개 타일
# [✓] '43' 분할 완료: 32개 타일
# [✓] '5' 분할 완료: 32개 타일
# [✓] '57' 분할 완료: 32개 타일
# [✓] '41' 분할 완료: 32개 타일
# [✓] '55' 분할 완료: 32개 타일
# [✓] '7' 분할 완료: 32개 타일
# [✓] '54' 분할 완료: 32개 타일
# [✓] '6' 분할 완료: 32개 타일
# [✓] '40' 분할 완료: 32개 타일
# [✓] '44' 분할 완료: 32개 타일
# [✓] '2' 분할 완료: 32개 타일
# [✓] '50' 분할 완료: 32개 타일
# [✓] '3' 분할 완료: 32개 타일
# [✓] '51' 분할 완료: 32개 타일
# [✓] '45' 분할 완료: 32개 타일
# [✓] '53' 분할 완료: 32개 타일
# [✓] '1' 분할 완료: 32개 타일
# [✓] '47' 분할 완료: 32개 타일
# [✓] '46' 분할 완료: 32개 타일
# [✓] '52' 분할 완료: 32개 타일
# [✓] 'Image040' 분할 완료: 16개 타일
# [✓] 'Image037' 분할 완료: 16개 타일
# [✓] 'Image036' 분할 완료: 16개 타일
# [✓] 'Image008' 분할 완료: 16개 타일
# [✓] 'Image034' 분할 완료: 16개 타일
# [✓] 'Image020' 분할 완료: 16개 타일
# [✓] 'Image035' 분할 완료: 16개 타일
# [✓] 'Image009' 분할 완료: 16개 타일
# [✓] 'Image031' 분할 완료: 16개 타일
# [✓] 'Image019' 분할 완료: 16개 타일
# [✓] 'Image018' 분할 완료: 16개 타일
# [✓] 'Image032' 분할 완료: 16개 타일
# [✓] 'Image033' 분할 완료: 16개 타일
# [✓] 'Image002' 분할 완료: 16개 타일
# [✓] 'Image016' 분할 완료: 16개 타일
# [✓] 'Image017' 분할 완료: 16개 타일
# [✓] 'Image003' 분할 완료: 16개 타일
# [✓] 'Image015' 분할 완료: 16개 타일
# [✓] 'Image001' 분할 완료: 16개 타일
# [✓] 'Image014' 분할 완료: 16개 타일
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 60
#      58 input_folder = "/Users/chonakyung/Library/CloudStorage/GoogleDrive-whskrud1007@gmail.com/내 드라이브/blood/Data/Raw_data/Train"
#      59 output_root  = "/Users/chonakyung/Library/CloudStorage/GoogleDrive-whskrud1007@gmail.com/내 드라이브/blood/Data/Cropped_Data/Train"
# ---> 60 split_folder(input_folder, output_root)
#
# Cell In[7], line 54, in split_folder(input_folder, output_root)
#      51 else:
#      52     rows, cols = 4, 4
# ---> 54 split_image(img_path, output_root, prefix=basename, rows=rows, cols=cols)
#
# Cell In[7], line 20, in split_image(input_path, output_dir, prefix, rows, cols)
#      17 right  = (col + 1) * tile_w if col < cols - 1 else W
#      18 lower  = (row + 1) * tile_h if row < rows - 1 else H
# ---> 20 tile = img.crop((left, upper, right, lower))
#      21 tile_filename = f"{prefix}_r{row}_c{col}.png"
#      22 tile.save(os.path.join(output_dir, tile_filename))
#
# File ~/Library/CloudStorage/GoogleDrive-whskrud1007@gmail.com/내 드라이브/blood/.venv/lib/python3.12/site-packages/PIL/Image.py:1303, in Image.crop(self, box)
#    1300     msg = "Coordinate 'lower' is less than 'upper'"
#    1301     raise ValueError(msg)
# -> 1303 self.load()
#    1304 return self._new(self._crop(self.im, box))
#
# File ~/Library/CloudStorage/GoogleDrive-whskrud1007@gmail.com/내 드라이브/blood/.venv/lib/python3.12/site-packages/PIL/ImageFile.py:370, in ImageFile.load(self)
#     368         read_bytes = next_offset - offset
#     369 try:
# --> 370     s = read(read_bytes)
#     371 except (IndexError, struct.error) as e:
#     372     # truncated png/gif
#     373     if LOAD_TRUNCATED_IMAGES:
#
# File ~/Library/CloudStorage/GoogleDrive-whskrud1007@gmail.com/내 드라이브/blood/.venv/lib/python3.12/site-packages/PIL/JpegImagePlugin.py:415, in JpegImageFile.load_read(self, read_bytes)
#     409 def load_read(self, read_bytes: int) -> bytes:
#     410     """
#     411     internal: read more image data
#     412     For premature EOF and LOAD_TRUNCATED_IMAGES adds EOI marker
#     413     so libjpeg can finish decoding
#     414     """
# --> 415     s = self.fp.read(read_bytes)
#     417     if not s and ImageFile.LOAD_TRUNCATED_IMAGES and not hasattr(self, "_ended"):
#     418         # Premature EOF.
#     419         # Pretend file is finished adding EOI marker
#     420         self._ended = True
#
# OSError: [Errno 89] Operation canceled
